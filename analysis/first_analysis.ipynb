# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("../data/official_data/train.csv",index_col="id")
test_df  = pd.read_csv("../data/official_data/test.csv",index_col="id")
x_train = train_df.drop("price_range",axis=1)
y_train = train_df["price_range"]

# %%
print(f"train shape : {train_df.shape}")
print(f"test shape : {test_df.shape}")
# Out:
# train shape : (1200, 21)
# test shape : (800, 20)

# %%
print(f"train is nan count: {train_df.isna().sum().sum()}")
print(f"test is nan count: {test_df.isna().sum().sum()}")
# Out:
# train is nan count: 0
# test is nan count: 0

# %%
for column in train_df.drop("price_range",axis=1).columns:
    # train_df.plot.scatter(x="price_range",y=column)
    # plt.title(column)
    # plt.show()
    pass

# %%
for column in train_df.drop("price_range",axis=1).columns:
    train_df[column].hist()
    plt.title(column)
    plt.show()
    pass
